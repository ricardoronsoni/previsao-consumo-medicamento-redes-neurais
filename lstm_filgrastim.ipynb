# %% [markdown]
# # Importações

# %%
# Importações
from pandas import DataFrame
from pandas import Series
from pandas import concat
from pandas import read_csv
from datetime import datetime
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.layers import LSTM
from keras.models import Sequential
from math import sqrt
from matplotlib import pyplot
import numpy
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Carregar dados

# %%
# Carregar os dados
dateparse = lambda dates: datetime.strptime(dates, '%Y-%m-%d')
series = read_csv('./dados/filgrastim_300mcg.csv', header=0, parse_dates=[0], index_col=0, date_parser=dateparse)

# %% [markdown]
# # Tratamento dados

# %%
# Transformar a série temporal em um dataframe adequado para aprendizado supervisionado
def timeseries_to_supervised(data, lag=1):
 df = DataFrame(data)
 columns = [df.shift(i) for i in range(1, lag+1)]
 columns.append(df)
 df = concat(columns, axis=1)
 df.fillna(0, inplace=True)
 return df

# %%
# Tornar a série estacionária por diferenciação para retirar a tendência
def difference(dataset, interval=1):
 diff = list()
 for i in range(interval, len(dataset)):
    value = dataset[i] - dataset[i - interval]
    diff.append(value)
 return Series(diff)

# Reverter a diferenciação para voltar a utilizar os dados
def inverse_difference(history, yhat, interval=1):
 return yhat + history[-interval]

# %%
# Dimensionar os dados (-1, 1)
def scale(train, test):
 # fit scaler
 scaler = MinMaxScaler(feature_range=(-1, 1))
 scaler = scaler.fit(train)
 # transform train
 train = train.reshape(train.shape[0], train.shape[1])
 train_scaled = scaler.transform(train)
 # transform test
 test = test.reshape(test.shape[0], test.shape[1])
 test_scaled = scaler.transform(test)
 return scaler, train_scaled, test_scaled

# Reverter a normalização para voltar a utilizar os dados
def invert_scale(scaler, X, value):
 new_row = [x for x in X] + [value]
 array = numpy.array(new_row)
 array = array.reshape(1, len(array))
 inverted = scaler.inverse_transform(array)
 return inverted[0, -1]

# %% [markdown]
# # Modelo LSTM

# %%
# Treinar e retornar o modelo LSTM
def fit_lstm(train, batch_size, nb_epoch, neurons):
 X, y = train[:, 0:-1], train[:, -1]
 X = X.reshape(X.shape[0], 1, X.shape[1])
 model = Sequential()
 model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
 model.add(layers.Dense(1))
 model.compile(loss='mean_squared_error', optimizer='adam')
 for i in range(nb_epoch):
    model.fit(X, y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)
    model.reset_states()
 return model

# %%
# Fazer a predição
def forecast(model, batch_size, row):
 X = row[0:-1]
 X = X.reshape(1, 1, len(X))
 yhat = model.predict(X, batch_size=batch_size)
 return yhat[0,0]

# One-step predição
def forecast_lstm(model, batch_size, X):
 X = X.reshape(1, 1, len(X))
 yhat = model.predict(X, batch_size=batch_size)
 return yhat[0,0]

# %%
# Transformar os dados em estacionários
raw_values = series.values
diff_values = difference(raw_values, 1)

# %%
# Transformar o layout do dataframe
supervised = timeseries_to_supervised(diff_values, 1)
supervised_values = supervised.values

# %%
# Criar as bases de treino e teste
train, test = supervised_values[0:-8], supervised_values[-8:]

# %%
# Dimensionar os dados
scaler, train_scaled, test_scaled = scale(train, test)

# %%
# Repetição da criação do modelo e predição em 30 vezes
error_scores = list()
predictions_complete = list()
for r in range(30):

  # Criar o modelo
  lstm_model = fit_lstm(train_scaled, 1, 1500, 2)

  # Treinar o modelo
  train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
  lstm_model.predict(train_reshaped, batch_size=1)

  # Validação walk-forward dos dados de teste
  predictions = list()

  for i in range(len(test_scaled)):

    # One-step predição
    X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
    yhat = forecast_lstm(lstm_model, 1, X)

    # Inverter a normalização
    yhat = invert_scale(scaler, X, yhat)

    # Inverter a diferenciação
    yhat = inverse_difference(raw_values, yhat, len(test_scaled)+1-i)

    # Armazenar a predição
    predictions.append(yhat)

  # Avaliar a performance
  rmse = sqrt(mean_squared_error(raw_values[-8:], predictions))
  print('Iteração %d - RMSE: %.4f' % (r+1, rmse))
  error_scores.append(rmse)

  # Salvar todos os dados previstos
  predictions_complete.append(predictions)
# Out:
# 27/27 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteração 1 - RMSE: 448.2291
# 27/27 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteração 2 - RMSE: 524.9130
# 27/27 [==============================] - 1s 2ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteração 3 - RMSE: 1052.0106
# 27/27 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteração 4 - RMSE: 517.5698
# 27/27 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# Iteração 5 - RMSE: 503.8243
# 27/27 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteração 6 - RMSE: 667.1840
# 27/27 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# Iteração 7 - RMSE: 494.4738
# 27/27 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# Iteração 8 - RMSE: 439.1219
# 27/27 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteração 9 - RMSE: 452.9822
# 27/27 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteração 10 - RMSE: 446.6395
# 27/27 [==============================] - 1s 2ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 28ms/step
# Iteração 11 - RMSE: 828.2260
# 27/27 [==============================] - 1s 2ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# Iteração 12 - RMSE: 536.0671
# 27/27 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# Iteração 13 - RMSE: 496.7042
# 27/27 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteração 14 - RMSE: 465.5783
# 27/27 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteração 15 - RMSE: 495.0094
# 27/27 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# Iteração 16 - RMSE: 488.7258
# 27/27 [==============================] - 1s 2ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 28ms/step
# Iteração 17 - RMSE: 610.1920
# 27/27 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# Iteração 18 - RMSE: 434.0250
# 27/27 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# Iteração 19 - RMSE: 432.1403
# 27/27 [==============================] - 1s 2ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# Iteração 20 - RMSE: 496.8414
# 27/27 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# Iteração 21 - RMSE: 397.6221
# 27/27 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteração 22 - RMSE: 3676.4835
# 27/27 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# Iteração 23 - RMSE: 762.2794
# 27/27 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteração 24 - RMSE: 436.2335
# 27/27 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# Iteração 25 - RMSE: 518.8935
# 27/27 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# Iteração 26 - RMSE: 771.8428
# 27/27 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Iteração 27 - RMSE: 460.5900
# 27/27 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteração 28 - RMSE: 469.1022
# 27/27 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Iteração 29 - RMSE: 484.4023
# 27/27 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Iteração 30 - RMSE: 498.4908

# %% [markdown]
# # Resultados

# %% [markdown]
# ## RMSE obtidos

# %%
# Preparação para apresentar os resultados obtidos
results = DataFrame()
results['rmse'] = error_scores

# %%
# Sumário do RMSE 
print("Sumário RMSE")
print(results.describe())
# Out:
# Sumário RMSE
#               rmse
# count    30.000000
# mean    643.546595
# std     590.406102
# min     397.622100
# 25%     454.884184
# 50%     495.856819
# 75%     533.278535
# max    3676.483543

# %%
# Bloxplot do RMSE
print("Bloxplot RMSE")
results.boxplot(grid=False)
# Out:
# Bloxplot RMSE
# <Axes: >

# %% [markdown]
# ## Predição com menor RMSE

# %%
# Plotar a predição com menor RMSE
print('Menor RMSE: %.4f' % (min(results['rmse'])))
plotar = series.reset_index()
plotar.loc[plotar.competencia > '2021-04-01', "predictions"] = predictions_complete[results['rmse'].idxmin()]
plotar = plotar.set_index('competencia')
pyplot.figure(figsize=(10,5))
pyplot.plot(plotar['qtd_dispensada'][0:-8])
pyplot.plot(plotar['qtd_dispensada'][-8:])
pyplot.plot(plotar['predictions'])
# Out:
# Menor RMSE: 397.6221

# %% [markdown]
# ## Predição com maior RMSE

# %%
# Plotar a predição com maior RMSE
print('Maior RMSE: %.4f' % (max(results['rmse'])))
plotar = series.reset_index()
plotar.loc[plotar.competencia > '2021-04-01', "predictions"] = predictions_complete[results['rmse'].idxmax()]
plotar = plotar.set_index('competencia')
pyplot.figure(figsize=(10,5))
pyplot.plot(plotar['qtd_dispensada'][0:-8])
pyplot.plot(plotar['qtd_dispensada'][-8:])
pyplot.plot(plotar['predictions'])
# Out:
# Maior RMSE: 3676.4835
